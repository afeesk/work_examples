# %% [markdown]
# # SAMPLING REPORTING

# %% [markdown]
# Data noise and class imbalance are two of the most common data quality issues that can affect the performance of most classification algorithms. A real-world dataset, however, contains a mixture of data noise and class imbalance.
#
# Several techniques such as sampling methods and cost-sensitive learning have been developed over the years to handle class imbalance issues. While some sampling methods are capable of filtering the data noise, the impact of the noise varies depending on the learning algorithm.
#
# Here, we offers a framework in the form of a python tool for selecting top performers from a wide range of techniques and learning algorithms for mining noisy and imbalance datasets for classification problems. The framework depends on imbalanced-learn, scikit-learn and numpy. The tool will be the go to tool for quick and easy experimentation and generation of reports on classification based problems.

# %%
from sampling_report.reporting.sampling_imblearn import sampling_report

# %%
help(sampling_report)
# Out:
# Help on function sampling_report in module sampling_report.reporting.sampling_imblearn:
#
# sampling_report(data: pandas.core.frame.DataFrame, target: str, model, random_state=None, class_weight=None, exclude=None, include=None)
#     :param data: Dataset including features and target.
#                  Notes: Dataset in the form of Pandas DataFrame.
#                  Dataset is expected to be preprocessed with no missing values.
#                  sampling_report can automatically handle categorical encoding.
#     :param target: str
#                    The class variable must be one of the columns in the data
#     :param model: Name of the model. Can be one or combination of:
#                   ['rf', 'tree', 'lg', 'gb', 'knn', 'nn', 'svm', 'linear_svm', 'nu_svm', 'nb', 'gnb', 'bnb', 'cnb']
#                   Notes: String or list is expected for single model. List is expected for multiple models.
#     :param random_state: int or RandomState instance, default=None
#                          Controls the randomness of the training and testing indices produced.
#                          Pass an int for reproducible output across multiple function calls
#     :param class_weight:  ‘balanced’ or 'balanced_subsample', default=None
#     :param include: str or list
#                     To include one or more of the sampling methods below:
#                     'EditedNearestNeighbours', 'RepeatedEditedNearestNeighbours', 'AllKNN',
#                    'NearMiss', 'NeighbourhoodCleaningRule', 'TomekLinks', 'ClusterCentroids',
#                    'CondensedNearestNeighbour', 'InstanceHardnessThreshold', 'OneSidedSelection',
#                    'RandomUnderSampler', 'ADASYN', 'BorderlineSMOTE', 'KMeansSMOTE', 'RandomOverSampler',
#                    'SMOTE', 'SVMSMOTE', 'SMOTEENN', 'SMOTETomek'
#     :param exclude: str or list
#                     To exclude one or more of the sampling methods below:
#                     'EditedNearestNeighbours', 'RepeatedEditedNearestNeighbours', 'AllKNN',
#                    'NearMiss', 'NeighbourhoodCleaningRule', 'TomekLinks', 'ClusterCentroids',
#                    'CondensedNearestNeighbour', 'InstanceHardnessThreshold', 'OneSidedSelection',
#                    'RandomUnderSampler', 'ADASYN', 'BorderlineSMOTE', 'KMeansSMOTE', 'RandomOverSampler',
#                    'SMOTE', 'SVMSMOTE', 'SMOTEENN', 'SMOTETomek'
#     :return: Sampling method, Class distribution after sampling, F1_macro, Accuracy,
#              Model name and Sampling strategy.

# %% [markdown]
# ### Load Data

# %% [markdown]
# The breast cancer dataset available at the UC Irvine Machine Learning Repository [1] [2] is widely used by researchers to demonstrate methods of dealing with noisy and imbalanced data.

# %% [markdown]
# The following packages are required to load the data.

# %%
import os
import pandas as pd

# %%
def load_data(file_name, col_name):
    file_path = os.path.join(os.getcwd(), 'dataset', file_name)
    data = pd.read_csv(file_path, names=col_name, header=None)
    return data

# %%
col_name = ['Class', 'age', 'menopause', 'tumor-size', 'inv-nodes', 
            'node-caps', 'deg-malig', 'breast', 'breast-quad', 'irradiat']
file_name='breast-cancer.data'
data =load_data(file_name, col_name)

# %%
data.shape
# Out:
# (286, 10)

# %%
data.head()
# Out:
#                   Class    age menopause tumor-size inv-nodes node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2        no
#
#    deg-malig breast breast-quad irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# 3          2  right     left_up       no
# 4          2  right   right_low       no

# %%
data.isnull().any()
# Out:
# Class          False
# age            False
# menopause      False
# tumor-size     False
# inv-nodes      False
# node-caps      False
# deg-malig      False
# breast         False
# breast-quad    False
# irradiat       False
# dtype: bool

# %%
data['Class'].value_counts()
# Out:
# no-recurrence-events    201
# recurrence-events        85
# Name: Class, dtype: int64

# %% [markdown]
# ### Target variable is imbalance

# %%
round((data['Class'].value_counts() / data['Class'].value_counts().sum())*100, 2)
# Out:
# no-recurrence-events    70.28
# recurrence-events       29.72
# Name: Class, dtype: float64

# %% [markdown]
# ### Investigate possible attribute noise

# %%
def get_attribute_noise(df, var, missing_val):
    df = df.copy()
    return df[df[var].str.strip().isin([missing_val])]

# %%
get_attribute_noise(df=data, var='node-caps', missing_val='?')
# Out:
#                     Class    age menopause tumor-size inv-nodes node-caps  \
# 145  no-recurrence-events  40-49   premeno      25-29       0-2         ?
# 163  no-recurrence-events  60-69      ge40      25-29       3-5         ?
# 164  no-recurrence-events  60-69      ge40      25-29       3-5         ?
# 183  no-recurrence-events  50-59      ge40      30-34      9-11         ?
# 184  no-recurrence-events  50-59      ge40      30-34      9-11         ?
# 233     recurrence-events  70-79      ge40      15-19      9-11         ?
# 263     recurrence-events  50-59      lt40      20-24       0-2         ?
# 264     recurrence-events  50-59      lt40      20-24       0-2         ?
#
#      deg-malig breast breast-quad irradiat
# 145          2   left   right_low      yes
# 163          1  right     left_up      yes
# 164          1  right    left_low      yes
# 183          3   left     left_up      yes
# 184          3   left    left_low      yes
# 233          1   left    left_low      yes
# 263          1   left     left_up       no
# 264          1   left    left_low       no

# %%
get_attribute_noise(df=data, var='breast-quad', missing_val='?')
# Out:
#                  Class    age menopause tumor-size inv-nodes node-caps  \
# 206  recurrence-events  50-59      ge40      30-34       0-2        no
#
#      deg-malig breast breast-quad irradiat
# 206          3   left           ?       no

# %% [markdown]
# ### Investigate possible class noise

# %%
def get_class_noise(df, class_name):
    df = df.copy()
    data_dedup_1 = df[~df.duplicated()]
    data_2 = data_dedup_1.drop([class_name], axis=1)
    data_dedup_2 = data_2[data_2.duplicated(keep=False)]
    df_final = df.iloc[data_dedup_2.index,]
    return df_final.sort_values(by=data_dedup_2.columns.tolist())

# %%
get_class_noise(df=data, class_name='Class')
# Out:
#                     Class    age menopause tumor-size inv-nodes node-caps  \
# 90   no-recurrence-events  30-39   premeno        0-4       0-2        no
# 205     recurrence-events  30-39   premeno        0-4       0-2        no
# 35   no-recurrence-events  30-39   premeno      30-34       0-2        no
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 210     recurrence-events  40-49   premeno      20-24       0-2        no
# 46   no-recurrence-events  40-49   premeno      25-29       0-2        no
# 236     recurrence-events  40-49   premeno      25-29       0-2        no
# 108  no-recurrence-events  40-49   premeno      30-34       0-2        no
# 212     recurrence-events  40-49   premeno      30-34       0-2        no
# 47   no-recurrence-events  50-59   premeno      25-29       0-2        no
# 213     recurrence-events  50-59   premeno      25-29       0-2        no
#
#      deg-malig breast breast-quad irradiat
# 90           2  right     central       no
# 205          2  right     central       no
# 35           2   left     left_up       no
# 281          2   left     left_up       no
# 2            2   left    left_low       no
# 210          2   left    left_low       no
# 46           2  right    left_low       no
# 236          2  right    left_low       no
# 108          3  right    right_up       no
# 212          3  right    right_up       no
# 47           1  right     left_up       no
# 213          1  right     left_up       no

# %%
def replace_cat_missing(df, var, val_to_replace=['?', ' ?'], suffix='_missing'):
    df = df.copy()
    df[var] = df[var].replace(val_to_replace, var+suffix)
    return df

# %%
VAR_WITH_MISSING_VALUES = ['node-caps', 'breast-quad']

# %%
for var in VAR_WITH_MISSING_VALUES:
    data = replace_cat_missing(df=data, var=var, val_to_replace='?', suffix='_missing')

# %% [markdown]
# ### Apply sampling_report

# %% [markdown]
# Demonstrate sampling reporting for random forest classifier without using class weight.

# %%
sampling_report(data=data, target='Class', model='rf', random_state=0)
# Out:
# EditedNearestNeighbours
# Class distribution after sampling: {'no-recurrence-events': 91, 'recurrence-events': 4}
# mean_f1: 0.875 | mean_acc: 0.97  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 91, 'recurrence-events': 85}
# mean_f1: 0.826 | mean_acc: 0.829  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 91, 'recurrence-events': 85}
# mean_f1: 0.826 | mean_acc: 0.829  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 4}
# mean_f1: 0.898 | mean_acc: 0.99  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# RepeatedEditedNearestNeighbours
# Class distribution after sampling: {'no-recurrence-events': 89}
# mean_f1: 1.0 | mean_acc: 1.0  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 67, 'recurrence-events': 85}
# mean_f1: 0.871 | mean_acc: 0.875  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 67, 'recurrence-events': 85}
# mean_f1: 0.871 | mean_acc: 0.875  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201}
# mean_f1: 1.0 | mean_acc: 1.0  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# AllKNN
# Class distribution after sampling: {'no-recurrence-events': 145}
# mean_f1: 1.0 | mean_acc: 1.0  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 83, 'recurrence-events': 85}
# mean_f1: 0.849 | mean_acc: 0.851  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 83, 'recurrence-events': 85}
# mean_f1: 0.849 | mean_acc: 0.851  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201}
# mean_f1: 1.0 | mean_acc: 1.0  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# NearMiss
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.679 | mean_acc: 0.682  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.711 | mean_acc: 0.712  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.711 | mean_acc: 0.712  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.651 | mean_acc: 0.742  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# NeighbourhoodCleaningRule
# Class distribution after sampling: {'no-recurrence-events': 99, 'recurrence-events': 37}
# mean_f1: 0.879 | mean_acc: 0.905  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 99, 'recurrence-events': 85}
# mean_f1: 0.783 | mean_acc: 0.787  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 99, 'recurrence-events': 85}
# mean_f1: 0.783 | mean_acc: 0.787  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 37}
# mean_f1: 0.762 | mean_acc: 0.895  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# TomekLinks
# Class distribution after sampling: {'no-recurrence-events': 186, 'recurrence-events': 70}
# mean_f1: 0.67 | mean_acc: 0.766  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 186, 'recurrence-events': 85}
# mean_f1: 0.648 | mean_acc: 0.723  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 186, 'recurrence-events': 85}
# mean_f1: 0.648 | mean_acc: 0.723  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 70}
# mean_f1: 0.67 | mean_acc: 0.782  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# ClusterCentroids
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.583 | mean_acc: 0.594  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.581 | mean_acc: 0.588  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.581 | mean_acc: 0.588  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.636 | mean_acc: 0.738  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# CondensedNearestNeighbour
# Class distribution after sampling: {'no-recurrence-events': 103, 'recurrence-events': 1}
# mean_f1: 0.895 | mean_acc: 0.981  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 103, 'recurrence-events': 85}
# mean_f1: 0.532 | mean_acc: 0.549  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 103, 'recurrence-events': 85}
# mean_f1: 0.532 | mean_acc: 0.549  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 1}
# mean_f1: 0.949 | mean_acc: 0.995  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# InstanceHardnessThreshold
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.831 | mean_acc: 0.835  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.831 | mean_acc: 0.835  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.831 | mean_acc: 0.835  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.669 | mean_acc: 0.756  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# OneSidedSelection
# Class distribution after sampling: {'no-recurrence-events': 200}
# mean_f1: 1.0 | mean_acc: 1.0  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 185, 'recurrence-events': 85}
# mean_f1: 0.662 | mean_acc: 0.733  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 185, 'recurrence-events': 85}
# mean_f1: 0.662 | mean_acc: 0.733  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201}
# mean_f1: 1.0 | mean_acc: 1.0  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# RandomUnderSampler
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.585 | mean_acc: 0.588  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.598 | mean_acc: 0.6  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
# Class distribution after sampling: {'no-recurrence-events': 85, 'recurrence-events': 85}
# mean_f1: 0.598 | mean_acc: 0.6  | model_name: RandomForestClassifier | sampling_strategy: majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.647 | mean_acc: 0.738  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
#
# ADASYN
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.777 | mean_acc: 0.779  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.777 | mean_acc: 0.779  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.777 | mean_acc: 0.779  | model_name: RandomForestClassifier | sampling_strategy: minority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.669 | mean_acc: 0.756  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
#
# BorderlineSMOTE
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.756 | mean_acc: 0.759  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.756 | mean_acc: 0.759  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.756 | mean_acc: 0.759  | model_name: RandomForestClassifier | sampling_strategy: minority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.669 | mean_acc: 0.756  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
#
# KMeansSMOTE
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.81 | mean_acc: 0.811  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.81 | mean_acc: 0.811  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.81 | mean_acc: 0.811  | model_name: RandomForestClassifier | sampling_strategy: minority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.669 | mean_acc: 0.756  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
#
# RandomOverSampler
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.835 | mean_acc: 0.836  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.835 | mean_acc: 0.836  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.835 | mean_acc: 0.836  | model_name: RandomForestClassifier | sampling_strategy: minority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.669 | mean_acc: 0.756  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
#
# SMOTE
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.776 | mean_acc: 0.779  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.776 | mean_acc: 0.779  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.776 | mean_acc: 0.779  | model_name: RandomForestClassifier | sampling_strategy: minority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.669 | mean_acc: 0.756  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
#
# SVMSMOTE
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.784 | mean_acc: 0.786  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.784 | mean_acc: 0.786  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 201}
# mean_f1: 0.784 | mean_acc: 0.786  | model_name: RandomForestClassifier | sampling_strategy: minority
#
# Class distribution after sampling: {'no-recurrence-events': 201, 'recurrence-events': 85}
# mean_f1: 0.669 | mean_acc: 0.756  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
#
# SMOTEENN
# Class distribution after sampling: {'no-recurrence-events': 84, 'recurrence-events': 128}
# mean_f1: 0.944 | mean_acc: 0.948  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 84, 'recurrence-events': 128}
# mean_f1: 0.944 | mean_acc: 0.948  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
# Class distribution after sampling: {'no-recurrence-events': 84, 'recurrence-events': 128}
# mean_f1: 0.944 | mean_acc: 0.948  | model_name: RandomForestClassifier | sampling_strategy: minority
#
# Class distribution after sampling: {'no-recurrence-events': 91, 'recurrence-events': 4}
# mean_f1: 0.875 | mean_acc: 0.97  | model_name: RandomForestClassifier | sampling_strategy: not minority
#
#
# SMOTETomek
# Class distribution after sampling: {'no-recurrence-events': 191, 'recurrence-events': 191}
# mean_f1: 0.784 | mean_acc: 0.785  | model_name: RandomForestClassifier | sampling_strategy: all
#
# Class distribution after sampling: {'no-recurrence-events': 191, 'recurrence-events': 191}
# mean_f1: 0.784 | mean_acc: 0.785  | model_name: RandomForestClassifier | sampling_strategy: not majority
#
# Class distribution after sampling: {'no-recurrence-events': 191, 'recurrence-events': 191}
# mean_f1: 0.784 | mean_acc: 0.785  | model_name: RandomForestClassifier | sampling_strategy: minority
#
# Class distribution after sampling: {'no-recurrence-events': 186, 'recurrence-events': 70}
# mean_f1: 0.67 | mean_acc: 0.766  | model_name: RandomForestClassifier | sampling_strategy: not minority

# %% [markdown]
# [1] Dua, D. and Graff, C. (2019). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.

# %% [markdown]
# [2] M. Zwitter, M. Soklic, University Medical Centre, Institute of Oncology, Ljubljana, Yugoslavia
